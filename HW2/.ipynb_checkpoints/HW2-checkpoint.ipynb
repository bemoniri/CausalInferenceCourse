# %%
import numpy as np
import pandas as pd
import csv

from itertools import combinations, permutations
import networkx as nx
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

from scipy import stats, linalg
import scipy
from scipy.stats import norm

x = np.random.randn(1, 10000)
y = x+0.02*np.random.randn(1, 10000)
z = x+y+0.02*np.random.randn(1, 10000)
w = x+y+z+0.02*np.random.randn(1, 10000)

da = np.transpose((np.concatenate((x, y, z, w), axis =0)))
print(da)
##################################################################################################
"""
Partial Correlation Calculatins and Cond. Independence Test
"""

def partial_corr(C):
    """
    Returns the sample linear partial correlation coefficients between pairs of variables in C, controlling 
    for the remaining variables in C.
    Parameters
    ----------
    C : array-like, shape (n, p)
        Array with the different variables. Each column of C is taken as a variable
    Returns
    -------
    P : array-like, shape (p, p)
        P[i, j] contains the partial correlation of C[:, i] and C[:, j] controlling
        for the remaining variables in C.
    """

    C = np.asarray(C)
    p = C.shape[1]
    P_corr = np.zeros((p, p), dtype=np.float)
    for i in range(p):
        P_corr[i, i] = 1
        for j in range(i+1, p):
            idx = np.ones(p, dtype=np.bool)
            idx[i] = False
            idx[j] = False
            beta_i = linalg.lstsq(C[:, idx], C[:, j])[0]
            beta_j = linalg.lstsq(C[:, idx], C[:, i])[0]

            res_j = C[:, j] - C[:, idx].dot( beta_i)
            res_i = C[:, i] - C[:, idx].dot(beta_j)
            
            corr = stats.pearsonr(res_i, res_j)[0]
            P_corr[i, j] = corr
            P_corr[j, i] = corr
    
    return P_corr

def test(data):
    parcorr = partial_corr(data)
    print(parcorr)
    parcorr = parcorr[0,1] 
    z = np.arctanh(parcorr)
    n = len(data[:,0])
    test_stat = np.sqrt(n-3)*z
    p_value = scipy.stats.norm.sf(abs(test_stat))*2 #twosided
    return p_value
    
####################################################################################################

# Loading Data

dag_data = np.genfromtxt('dag.csv', delimiter=',')
data = dag_data[1:,1:]

####################################################################################################

# Nodes of the graph
nodes = range(4)
l = -1
#dm = np.array(bin_data).reshape((5000, 4))

# Creating the full undirected graph to start with:
Graph = nx.Graph()
Graph.add_nodes_from(nodes)

for (i, j) in combinations(nodes, 2):
    Graph.add_edge(i, j)
    pass

alpha = 0.05


pos = nx.spring_layout(Graph)
plt.figure()
nx.draw_networkx(Graph,pos=pos)
plt.show()

while True:
    l = l + 1
    for (i, j) in permutations(nodes, 2):
        adjacents = list(Graph.neighbors(i))
        if j in adjacents:
            adjacents.remove(j)
            if len(adjacents)>=l:
                for S in combinations(adjacents, l):
                    print("(%d, %d), S = %s" %(i, j, str(S)))
                    set_to_test = [i, j] + list(S)
                    test_data = da[:,set_to_test]
                    print(test_data)
                    pval = test(test_data)
                    if pval > alpha:
                        Graph.remove_edge(i, j)
                        plt.figure()
                        nx.draw_networkx(Graph,pos=pos)
                        plt.show()
                        break
    print(Graph.number_of_nodes())
    
    if(Graph.number_of_nodes()>l):
        break
# Out:
# [[-0.57911917 -0.59271275 -1.15829282 -2.32556605]
#  [-0.18206596 -0.17938948 -0.36316784 -0.72340679]
#  [-1.11879764 -1.09395447 -2.20916896 -4.41354248]
#  ...
#  [ 0.6233358   0.59372729  1.22591197  2.44468023]
#  [-0.89958153 -0.88406515 -1.78132084 -3.55287153]
#  [ 0.33612545  0.31724255  0.6487378   1.28791296]]
# (0, 1), S = ()
# [[-0.57911917 -0.59271275]
#  [-0.18206596 -0.17938948]
#  [-1.11879764 -1.09395447]
#  ...
#  [ 0.6233358   0.59372729]
#  [-0.89958153 -0.88406515]
#  [ 0.33612545  0.31724255]]
# [[1.         0.99980268]
#  [0.99980268 1.        ]]
# (0, 2), S = ()
# [[-0.57911917 -1.15829282]
#  [-0.18206596 -0.36316784]
#  [-1.11879764 -2.20916896]
#  ...
#  [ 0.6233358   1.22591197]
#  [-0.89958153 -1.78132084]
#  [ 0.33612545  0.6487378 ]]
# [[1.         0.99989977]
#  [0.99989977 1.        ]]
# (0, 3), S = ()
# [[-0.57911917 -2.32556605]
#  [-0.18206596 -0.72340679]
#  [-1.11879764 -4.41354248]
#  ...
#  [ 0.6233358   2.44468023]
#  [-0.89958153 -3.55287153]
#  [ 0.33612545  1.28791296]]
# [[1.         0.99992463]
#  [0.99992463 1.        ]]
# (1, 0), S = ()
# [[-0.59271275 -0.57911917]
#  [-0.17938948 -0.18206596]
#  [-1.09395447 -1.11879764]
#  ...
#  [ 0.59372729  0.6233358 ]
#  [-0.88406515 -0.89958153]
#  [ 0.31724255  0.33612545]]
# [[1.         0.99980268]
#  [0.99980268 1.        ]]
# (1, 2), S = ()
# [[-0.59271275 -1.15829282]
#  [-0.17938948 -0.36316784]
#  [-1.09395447 -2.20916896]
#  ...
#  [ 0.59372729  1.22591197]
#  [-0.88406515 -1.78132084]
#  [ 0.31724255  0.6487378 ]]
# [[1.         0.99990469]
#  [0.99990469 1.        ]]
# (1, 3), S = ()
# [[-0.59271275 -2.32556605]
#  [-0.17938948 -0.72340679]
#  [-1.09395447 -4.41354248]
#  ...
#  [ 0.59372729  2.44468023]
#  [-0.88406515 -3.55287153]
#  [ 0.31724255  1.28791296]]
# [[1.         0.99992825]
#  [0.99992825 1.        ]]
# (2, 0), S = ()
# [[-1.15829282 -0.57911917]
#  [-0.36316784 -0.18206596]
#  [-2.20916896 -1.11879764]
#  ...
#  [ 1.22591197  0.6233358 ]
#  [-1.78132084 -0.89958153]
#  [ 0.6487378   0.33612545]]
# [[1.         0.99989977]
#  [0.99989977 1.        ]]
# (2, 1), S = ()
# [[-1.15829282 -0.59271275]
#  [-0.36316784 -0.17938948]
#  [-2.20916896 -1.09395447]
#  ...
#  [ 1.22591197  0.59372729]
#  [-1.78132084 -0.88406515]
#  [ 0.6487378   0.31724255]]
# [[1.         0.99990469]
#  [0.99990469 1.        ]]
# (2, 3), S = ()
# [[-1.15829282 -2.32556605]
#  [-0.36316784 -0.72340679]
#  [-2.20916896 -4.41354248]
#  ...
#  [ 1.22591197  2.44468023]
#  [-1.78132084 -3.55287153]
#  [ 0.6487378   1.28791296]]
# [[1.         0.99997612]
#  [0.99997612 1.        ]]
# (3, 0), S = ()
# [[-2.32556605 -0.57911917]
#  [-0.72340679 -0.18206596]
#  [-4.41354248 -1.11879764]
#  ...
#  [ 2.44468023  0.6233358 ]
#  [-3.55287153 -0.89958153]
#  [ 1.28791296  0.33612545]]
# [[1.         0.99992463]
#  [0.99992463 1.        ]]
# (3, 1), S = ()
# [[-2.32556605 -0.59271275]
#  [-0.72340679 -0.17938948]
#  [-4.41354248 -1.09395447]
#  ...
#  [ 2.44468023  0.59372729]
#  [-3.55287153 -0.88406515]
#  [ 1.28791296  0.31724255]]
# [[1.         0.99992825]
#  [0.99992825 1.        ]]
# (3, 2), S = ()
# [[-2.32556605 -1.15829282]
#  [-0.72340679 -0.36316784]
#  [-4.41354248 -2.20916896]
#  ...
#  [ 2.44468023  1.22591197]
#  [-3.55287153 -1.78132084]
#  [ 1.28791296  0.6487378 ]]
# [[1.         0.99997612]
#  [0.99997612 1.        ]]
# 4

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from scipy.stats import norm
dag_data = np.genfromtxt('test.csv', delimiter=',')
data = dag_data

def test (data, x, y, set):
    if (len(set) == 0):
        data_x = data[:, x]
        data_y = data[:, y]
        r = np.corrcoef(data_x, data_y)
        r = r[1,0]
        t = 0.5*np.log((1+r)/(1-r))        
        n = len(data_x)        
        z = t/(1/np.sqrt(n-3))
        p1 = norm.cdf(z)
        p2 = 1-norm.cdf(z)
        pval = 2*min(p1, p2)
        
    else:
        data_x = data[:, x]
        data_y = data[:, y]
        j = 0
        data_z = np.zeros([len(data_x), len(set)])
        for i in set:
            data_z[:, j] = data[:, i]
            j += 1
            
        reg = LinearRegression().fit(data_z, data_x)
        pred_x = reg.predict(data_z)
        residual_x = pred_x - data_x
        
        
        reg = LinearRegression().fit(data_z, data_y)
        pred_y = reg.predict(data_z)
        residual_y = data_y - pred_y
        
        
        partial_corr = np.corrcoef(residual_y, residual_x)
        partial_corr = partial_corr[1, 0]
        
        z = 0.5*np.log((1+partial_corr)/(1-partial_corr))
        r = np.corrcoef(data_x, data_y)
        r = r[0, 1]
        z = (z - 0.5*(np.log((1+r)/(1-r))))*np.sqrt(len(data_x)-3)
        p1 = norm.cdf(z)
        p2 = 1-norm.cdf(z)
        pval = 2*min(p1, p2)
        print(pval*100)
               
               
                
test(data, 0, 1, 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-f46a8db2c3a9> in <module>()
#      51
#      52
# ---> 53 test(data, 0, 1, 3)
#
# <ipython-input-8-f46a8db2c3a9> in test(data, x, y, set)
#       6
#       7 def test (data, x, y, set):
# ----> 8     if (len(set) == 0):
#       9         data_x = data[:, x]
#      10         data_y = data[:, y]
#
# TypeError: object of type 'int' has no len()
